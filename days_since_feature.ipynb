# %%
import pandas as pd

# %%
v5 = pd.read_csv('./assets/skunkworks_data_v5.csv')

# %%
v5.head(10)
# Out:
#         Date                        Type          Fund           Campaign  \
# 0  9/25/2024                    Donation  Unrestricted  Support The River
# 1  9/25/2024  Recurring Donation Payment  Unrestricted  Support The River
# 2  9/24/2024                    Donation  Unrestricted  Support The River
# 3  9/24/2024                    Donation  Unrestricted  Support The River
# 4  9/24/2024                    Donation  Unrestricted  Support The River
# 5  9/24/2024                    Donation  Unrestricted  Support The River
# 6  9/24/2024                    Donation  Unrestricted  Support The River
# 7  9/22/2024                    Donation  Unrestricted  Support The River
# 8  9/21/2024                    Donation  Unrestricted  Support The River
# 9  9/21/2024                    Donation  Unrestricted  Support The River
#
#                      Appeal    Zip  Account Number  Quarter  DayOfWeek  \
# 0         Individual Online  53704            2574        3          2
# 1         Individual Online  53590            2692        3          2
# 2  Individual Multi Channel  53590             313        3          1
# 3         Individual Online  53715           20745        3          1
# 4  Individual Multi Channel  53703             310        3          1
# 5  Individual Multi Channel  53705             309        3          1
# 6  Individual Multi Channel  53705             312        3          1
# 7         Individual Online  53716            5756        3          6
# 8         Individual Online  53716           19400        3          5
# 9         Individual Online  53719           20438        3          5
#
#    Season  Proximity to Holiday      5 Day Window Type Mode  \
# 0       4                     7  Recurring Donation Payment
# 1       4                     7  Recurring Donation Payment
# 2       4                     8  Recurring Donation Payment
# 3       4                     8  Recurring Donation Payment
# 4       4                     8  Recurring Donation Payment
# 5       4                     8  Recurring Donation Payment
# 6       4                     8  Recurring Donation Payment
# 7       4                    10  Recurring Donation Payment
# 8       4                    11  Recurring Donation Payment
# 9       4                    11  Recurring Donation Payment
#
#   5 Day Window Appeal Mode 5 Day Window Campaign Mode 5 Day Window Fund Mode  \
# 0        Individual Online          Support The River           Unrestricted
# 1        Individual Online          Support The River           Unrestricted
# 2        Individual Online          Support The River           Unrestricted
# 3        Individual Online          Support The River           Unrestricted
# 4        Individual Online          Support The River           Unrestricted
# 5        Individual Online          Support The River           Unrestricted
# 6        Individual Online          Support The River           Unrestricted
# 7        Individual Online          Support The River           Unrestricted
# 8        Individual Online          Support The River           Unrestricted
# 9        Individual Online          Support The River           Unrestricted
#
#    5_Day_Window_Count
# 0                  42
# 1                  42
# 2                  42
# 3                  42
# 4                  42
# 5                  42
# 6                  42
# 7                  42
# 8                  42
# 9                  42

# %%
v5['Date'] = pd.to_datetime(v5['Date'])

# %%
v5.head()
# Out:
#         Date                        Type          Fund           Campaign  \
# 0 2024-09-25                    Donation  Unrestricted  Support The River
# 1 2024-09-25  Recurring Donation Payment  Unrestricted  Support The River
# 2 2024-09-24                    Donation  Unrestricted  Support The River
# 3 2024-09-24                    Donation  Unrestricted  Support The River
# 4 2024-09-24                    Donation  Unrestricted  Support The River
#
#                      Appeal    Zip  Account Number  Quarter  DayOfWeek  \
# 0         Individual Online  53704            2574        3          2
# 1         Individual Online  53590            2692        3          2
# 2  Individual Multi Channel  53590             313        3          1
# 3         Individual Online  53715           20745        3          1
# 4  Individual Multi Channel  53703             310        3          1
#
#    Season  Proximity to Holiday      5 Day Window Type Mode  \
# 0       4                     7  Recurring Donation Payment
# 1       4                     7  Recurring Donation Payment
# 2       4                     8  Recurring Donation Payment
# 3       4                     8  Recurring Donation Payment
# 4       4                     8  Recurring Donation Payment
#
#   5 Day Window Appeal Mode 5 Day Window Campaign Mode 5 Day Window Fund Mode  \
# 0        Individual Online          Support The River           Unrestricted
# 1        Individual Online          Support The River           Unrestricted
# 2        Individual Online          Support The River           Unrestricted
# 3        Individual Online          Support The River           Unrestricted
# 4        Individual Online          Support The River           Unrestricted
#
#    5_Day_Window_Count
# 0                  42
# 1                  42
# 2                  42
# 3                  42
# 4                  42

# %%
campaign_first_dates = v5.groupby('Campaign')['Date'].min()

# %%
print(campaign_first_dates)
# Out:
# Campaign
# 2023 Full Summer for All        2023-06-04
# 2023 Giving Tuesday             2023-11-21
# 2023 HOPE                       2023-10-26
# 2023 HOPE - Sponsor             2023-11-10
# 2023 ReMitts                    2023-10-17
# 2023 Sips & Slices              2023-08-08
# 2023 Sips & Slices - Sponsor    2023-09-10
# 2023 Year-End                   2023-11-09
# 2023-2024 Recipe for Hope       2023-01-20
# 2024 Breakfast with the Bunny   2024-03-25
# 2024 Match Madness              2024-01-29
# 2024 ReMitts                    2024-01-30
# 2024 Sips & Slices              2024-06-28
# 2024 Sips & Slices - Sponsor    2024-07-30
# In-Kind                         2023-01-19
# Match Madness 2023              2023-03-02
# Support The River               2023-01-01
# Year-End 2022                   2023-01-01
# Name: Date, dtype: datetime64[ns]

# %%
v5['Days_Since_Campaign_Start'] = v5.apply(
    lambda row: (row['Date'] - campaign_first_dates[row['Campaign']]).days,
    axis=1
)

# %%
print(v5[['Date', 'Campaign', 'Days_Since_Campaign_Start']].head(10))
# Out:
#         Date           Campaign  Days_Since_Campaign_Start
# 0 2024-09-25  Support The River                        633
# 1 2024-09-25  Support The River                        633
# 2 2024-09-24  Support The River                        632
# 3 2024-09-24  Support The River                        632
# 4 2024-09-24  Support The River                        632
# 5 2024-09-24  Support The River                        632
# 6 2024-09-24  Support The River                        632
# 7 2024-09-22  Support The River                        630
# 8 2024-09-21  Support The River                        629
# 9 2024-09-21  Support The River                        629

# %%
v5.head()
# Out:
#         Date                        Type          Fund           Campaign  \
# 0 2024-09-25                    Donation  Unrestricted  Support The River
# 1 2024-09-25  Recurring Donation Payment  Unrestricted  Support The River
# 2 2024-09-24                    Donation  Unrestricted  Support The River
# 3 2024-09-24                    Donation  Unrestricted  Support The River
# 4 2024-09-24                    Donation  Unrestricted  Support The River
#
#                      Appeal    Zip  Account Number  Quarter  DayOfWeek  \
# 0         Individual Online  53704            2574        3          2
# 1         Individual Online  53590            2692        3          2
# 2  Individual Multi Channel  53590             313        3          1
# 3         Individual Online  53715           20745        3          1
# 4  Individual Multi Channel  53703             310        3          1
#
#    Season  Proximity to Holiday      5 Day Window Type Mode  \
# 0       4                     7  Recurring Donation Payment
# 1       4                     7  Recurring Donation Payment
# 2       4                     8  Recurring Donation Payment
# 3       4                     8  Recurring Donation Payment
# 4       4                     8  Recurring Donation Payment
#
#   5 Day Window Appeal Mode 5 Day Window Campaign Mode 5 Day Window Fund Mode  \
# 0        Individual Online          Support The River           Unrestricted
# 1        Individual Online          Support The River           Unrestricted
# 2        Individual Online          Support The River           Unrestricted
# 3        Individual Online          Support The River           Unrestricted
# 4        Individual Online          Support The River           Unrestricted
#
#    5_Day_Window_Count  Days_Since_Campaign_Start
# 0                  42                        633
# 1                  42                        633
# 2                  42                        632
# 3                  42                        632
# 4                  42                        632

# %%
v5.to_csv('./assets/skunkworks_data_v6.csv', index=False)

# %%
campaign_counts = v5['Campaign'].value_counts()
print("Campaign Counts:")
print(campaign_counts)
# Out:
# Campaign Counts:
# Campaign
# Support The River                7586
# 2023 HOPE                         250
# 2024 Sips & Slices                219
# 2023 Year-End                     195
# 2023-2024 Recipe for Hope         181
# In-Kind                           160
# 2023 Full Summer for All          153
# 2023 Giving Tuesday               124
# 2023 Sips & Slices                112
# 2023 ReMitts                      107
# 2024 Match Madness                 85
# Match Madness 2023                 75
# Year-End 2022                      10
# 2024 ReMitts                        6
# 2024 Sips & Slices - Sponsor        2
# 2024 Breakfast with the Bunny       1
# 2023 HOPE - Sponsor                 1
# 2023 Sips & Slices - Sponsor        1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Create the histogram
plt.figure(figsize=(12, 6))  # Set figure size
campaign_counts.plot(kind='bar')

# Customize the plot
plt.title('Number of Appearances by Campaign')
plt.xlabel('Campaign Name')
plt.ylabel('Number of Appearances')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adjust layout to prevent label cutoff
plt.tight_layout()

# Show the plot
plt.show()
